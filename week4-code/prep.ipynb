# %% [markdown]
# # Flights prep
#
# Preparing data for the D3 class.
#
# Let's grab flights.

# %%
import pandas as pd

flights = pd.read_csv("../../../../week2/data/flights.csv")

flights
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0                1  2013      1    1     517.0             515        2.0
# 1                2  2013      1    1     533.0             529        4.0
# 2                3  2013      1    1     542.0             540        2.0
# 3                4  2013      1    1     544.0             545       -1.0
# 4                5  2013      1    1     554.0             600       -6.0
# ...            ...   ...    ...  ...       ...             ...        ...
# 336771      336772  2013      9   30       NaN            1455        NaN
# 336772      336773  2013      9   30       NaN            2200        NaN
# 336773      336774  2013      9   30       NaN            1210        NaN
# 336774      336775  2013      9   30       NaN            1159        NaN
# 336775      336776  2013      9   30       NaN             840        NaN
#
#         arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# ...

# %% [markdown]
# I want the top 20 destinations and their counts, sorted.

# %%
flights.groupby("dest").size().sort_values(ascending=False)[0:20].to_csv()
# Out:
# 'dest,0\nORD,17283\nATL,17215\nLAX,16174\nBOS,15508\nMCO,14082\nCLT,14064\nSFO,13331\nFLL,12055\nMIA,11728\nDCA,9705\nDTW,9384\nDFW,8738\nRDU,8163\nTPA,7466\nDEN,7266\nIAH,7198\nMSP,7185\nPBI,6554\nBNA,6333\nLAS,5997\n'
